# %% [markdown]
# Lecture 1: Basic Knowledge of PyTorch
#
# Zhang Huaizheng
# huaizhen001@e.ntu.edu.sg
# http://zhanghuaizheng.info/PyTorch4DL

# %% [markdown]
# Comparison: Numpy and PyTorch

# %%
import numpy as np

x = np.array([[1, 2, 3],
              [4, 5, 6]])
y = np.array([[2, 2, 2],
              [2, 2, 2]])
z = np.array([[3, 3, 3],
              [3, 3, 3]])

a = x * y
b = a + z
c = np.sum(b)

grad_c = 1.0
grad_b = grad_c * np.ones(b.shape)
grad_a = grad_b.copy()
grad_z = grad_b.copy()
grad_x = grad_a * y
grad_y = grad_a * x

print grad_x
print grad_y
# Out:
# [[ 2.  2.  2.]
#  [ 2.  2.  2.]]
# [[ 1.  2.  3.]
#  [ 4.  5.  6.]]

# %%
import torch
from torch.autograd import Variable

x = Variable(torch.Tensor([[1, 2, 3],
                           [4, 5, 6]]), requires_grad=True)
y = Variable(torch.Tensor([[2, 2, 2],
                           [2, 2, 2]]), requires_grad=True)
z = Variable(torch.Tensor([[3, 3, 3],
                           [3, 3, 3]]), requires_grad=True)

a = x * y
b = a + z
c = torch.sum(b)

c.backward()

print x.grad.data
print y.grad.data
# Out:
#  2  2  2
#  2  2  2
# [torch.FloatTensor of size 2x3]
#
#
#  1  2  3
#  4  5  6
# [torch.FloatTensor of size 2x3]

# %% [markdown]
# Comparison: Tensorflow and PyTorch

# %%
import tensorflow as tf
import numpy as np

N, D_in, H, D_out = 64, 1000, 100, 10

x = tf.placeholder(tf.float32, shape=(None, D_in))
y = tf.placeholder(tf.float32, shape=(None, D_out))

w1 = tf.Variable(tf.random_normal((D_in, H)))
w2 = tf.Variable(tf.random_normal((H, D_out)))

h = tf.matmul(x, w1)
h_relu = tf.maximum(h, tf.zeros(1))
y_pred = tf.matmul(h_relu, w2)

loss = tf.reduce_sum((y - y_pred) ** 2.0)

grad_w1, grad_w2 = tf.gradients(loss, [w1, w2])

learning_rate = 1e-6
new_w1 = w1.assign(w1 - learning_rate * grad_w1)
new_w2 = w2.assign(w2 - learning_rate * grad_w2)


with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())

    x_value = np.random.randn(N, D_in)
    y_value = np.random.randn(N, D_out)
    
    for i in range(500):
        
        loss_value, grad_w1_value, grad_w1_value = sess.run([loss, new_w1, new_w2],
                                    feed_dict={x: x_value, y: y_value})
        print("Iteration " + str(i) + "th: the loss is " + str(loss_value))
# Out:
# Iteration 0th: the loss is 2.6601e+07
# Iteration 1th: the loss is 2.04535e+07
# Iteration 2th: the loss is 1.81108e+07
# Iteration 3th: the loss is 1.69335e+07
# Iteration 4th: the loss is 1.56103e+07
# Iteration 5th: the loss is 1.36054e+07
# Iteration 6th: the loss is 1.10008e+07
# Iteration 7th: the loss is 8.25942e+06
# Iteration 8th: the loss is 5.86117e+06
# Iteration 9th: the loss is 4.0136e+06
# Iteration 10th: the loss is 2.71823e+06
# Iteration 11th: the loss is 1.85464e+06
# Iteration 12th: the loss is 1.29425e+06
# Iteration 13th: the loss is 930967.0
# Iteration 14th: the loss is 693112.0
# Iteration 15th: the loss is 533728.0
# Iteration 16th: the loss is 423590.0
# Iteration 17th: the loss is 344818.0
# Iteration 18th: the loss is 286715.0
# Iteration 19th: the loss is 242350.0
# Iteration 20th: the loss is 207456.0
# Iteration 21th: the loss is 179340.0
# Iteration 22th: the loss is 156249.0
# Iteration 23th: the loss is 136985.0
# Iteration 24th: the loss is 120713.0
# Iteration 25th: the loss is 106843.0
# Iteration 26th: the loss is 94905.1
# Iteration 27th: the loss is 84572.1
# Iteration 28th: the loss is 75571.6
# Iteration 29th: the loss is 67695.8
# Iteration 30th: the loss is 60776.0
# Iteration 31th: the loss is 54678.5
# Iteration 32th: the loss is 49285.1
# Iteration 33th: the loss is 44509.7
# Iteration 34th: the loss is 40266.3
# Iteration 35th: the loss is 36484.6
# Iteration 36th: the loss is 33108.3
# Iteration 37th: the loss is 30087.7
# Iteration 38th: the loss is 27380.8
# Iteration 39th: the loss is 24951.6
# Iteration 40th: the loss is 22765.8
# Iteration 41th: the loss is 20796.5
# Iteration 42th: the loss is 19020.2
# Iteration 43th: the loss is 17417.3
# Iteration 44th: the loss is 15966.9
# Iteration 45th: the loss is 14654.4
# Iteration 46th: the loss is 13464.4
# Iteration 47th: the loss is 12384.3
# Iteration 48th: the loss is 11402.3
# Iteration 49th: the loss is 10508.1
# Iteration 50th: the loss is 9693.1
# Iteration 51th: the loss is 8950.17
# Iteration 52th: the loss is 8272.04
# Iteration 53th: the loss is 7651.43
# Iteration 54th: the loss is 7082.98
# Iteration 55th: the loss is 6562.31
# Iteration 56th: the loss is 6084.12
# Iteration 57th: the loss is 5644.96
# Iteration 58th: the loss is 5241.24
# Iteration 59th: the loss is 4869.68
# Iteration 60th: the loss is 4527.51
# Iteration 61th: the loss is 4212.1
# Iteration 62th: the loss is 3921.15
# Iteration 63th: the loss is 3652.69
# Iteration 64th: the loss is 3404.51
# Iteration 65th: the loss is 3175.13
# Iteration 66th: the loss is 2962.94
# Iteration 67th: the loss is 2766.53
# Iteration 68th: the loss is 2584.52
# Iteration 69th: the loss is 2415.77
# Iteration 70th: the loss is 2259.18
# Iteration 71th: the loss is 2113.85
# Iteration 72th: the loss is 1978.78
# Iteration 73th: the loss is 1853.2
# Iteration 74th: the loss is 1736.39
# Iteration 75th: the loss is 1627.7
# Iteration 76th: the loss is 1526.47
# Iteration 77th: the loss is 1432.14
# Iteration 78th: the loss is 1344.19
# Iteration 79th: the loss is 1262.21
# Iteration 80th: the loss is 1185.64
# Iteration 81th: the loss is 1114.16
# Iteration 82th: the loss is 1047.36
# Iteration 83th: the loss is 984.916
# Iteration 84th: the loss is 926.528
# Iteration 85th: the loss is 871.904
# Iteration 86th: the loss is 820.771
# Iteration 87th: the loss is 772.912
# Iteration 88th: the loss is 728.063
# Iteration 89th: the loss is 686.01
# Iteration 90th: the loss is 646.577
# Iteration 91th: the loss is 609.596
# Iteration 92th: the loss is 574.903
# Iteration 93th: the loss is 542.344
# Iteration 94th: the loss is 511.76
# Iteration 95th: the loss is 483.029
# Iteration 96th: the loss is 456.034
# Iteration 97th: the loss is 430.638
# Iteration 98th: the loss is 406.759
# Iteration 99th: the loss is 384.294
# Iteration 100th: the loss is 363.158
# Iteration 101th: the loss is 343.252
# Iteration 102th: the loss is 324.511
# Iteration 103th: the loss is 306.854
# Iteration 104th: the loss is 290.217
# Iteration 105th: the loss is 274.541
# Iteration 106th: the loss is 259.754
# Iteration 107th: the loss is 245.812
# Iteration 108th: the loss is 232.661
# Iteration 109th: the loss is 220.251
# Iteration 110th: the loss is 208.543
# Iteration 111th: the loss is 197.486
# Iteration 112th: the loss is 187.046
# Iteration 113th: the loss is 177.192
# Iteration 114th: the loss is 167.879
# Iteration 115th: the loss is 159.081
# Iteration 116th: the loss is 150.765
# Iteration 117th: the loss is 142.909
# Iteration 118th: the loss is 135.484
# Iteration 119th: the loss is 128.46
# Iteration 120th: the loss is 121.817
# Iteration 121th: the loss is 115.533
# Iteration 122th: the loss is 109.589
# Iteration 123th: the loss is 103.961
# Iteration 124th: the loss is 98.6343
# Iteration 125th: the loss is 93.5912
# Iteration 126th: the loss is 88.8164
# Iteration 127th: the loss is 84.2946
# Iteration 128th: the loss is 80.0115
# Iteration 129th: the loss is 75.9531
# Iteration 130th: the loss is 72.1101
# Iteration 131th: the loss is 68.4684
# Iteration 132th: the loss is 65.0149
# Iteration 133th: the loss is 61.7431
# Iteration 134th: the loss is 58.6416
# Iteration 135th: the loss is 55.6998
# Iteration 136th: the loss is 52.9116
# Iteration 137th: the loss is 50.2663
# Iteration 138th: the loss is 47.7574
# Iteration 139th: the loss is 45.3786
# Iteration 140th: the loss is 43.1211
# Iteration 141th: the loss is 40.979
# Iteration 142th: the loss is 38.9472
# Iteration 143th: the loss is 37.0183
# Iteration 144th: the loss is 35.1871
# Iteration 145th: the loss is 33.4491
# Iteration 146th: the loss is 31.7993
# Iteration 147th: the loss is 30.2331
# Iteration 148th: the loss is 28.7464
# Iteration 149th: the loss is 27.3342
# Iteration 150th: the loss is 25.9936
# Iteration 151th: the loss is 24.7199
# Iteration 152th: the loss is 23.5101
# Iteration 153th: the loss is 22.361
# Iteration 154th: the loss is 21.2689
# Iteration 155th: the loss is 20.2315
# Iteration 156th: the loss is 19.2462
# Iteration 157th: the loss is 18.3102
# Iteration 158th: the loss is 17.42
# Iteration 159th: the loss is 16.5743
# Iteration 160th: the loss is 15.7702
# Iteration 161th: the loss is 15.0063
# Iteration 162th: the loss is 14.2796
# Iteration 163th: the loss is 13.5894
# Iteration 164th: the loss is 12.9327
# Iteration 165th: the loss is 12.3089
# Iteration 166th: the loss is 11.7156
# Iteration 167th: the loss is 11.1511
# Iteration 168th: the loss is 10.6144
# Iteration 169th: the loss is 10.1042
# Iteration 170th: the loss is 9.61856
# Iteration 171th: the loss is 9.15701
# Iteration 172th: the loss is 8.71796
# Iteration 173th: the loss is 8.30001
# Iteration 174th: the loss is 7.9028
# Iteration 175th: the loss is 7.52494
# Iteration 176th: the loss is 7.16519
# Iteration 177th: the loss is 6.8231
# Iteration 178th: the loss is 6.49726
# Iteration 179th: the loss is 6.18757
# Iteration 180th: the loss is 5.89258
# Iteration 181th: the loss is 5.61205
# Iteration 182th: the loss is 5.34516
# Iteration 183th: the loss is 5.09087
# Iteration 184th: the loss is 4.84895
# Iteration 185th: the loss is 4.61874
# Iteration 186th: the loss is 4.39951
# Iteration 187th: the loss is 4.19108
# Iteration 188th: the loss is 3.99243
# Iteration 189th: the loss is 3.80335
# Iteration 190th: the loss is 3.62331
# Iteration 191th: the loss is 3.45192
# Iteration 192th: the loss is 3.28894
# Iteration 193th: the loss is 3.13358
# Iteration 194th: the loss is 2.98566
# Iteration 195th: the loss is 2.84473
# Iteration 196th: the loss is 2.71076
# Iteration 197th: the loss is 2.58297
# Iteration 198th: the loss is 2.46135
# Iteration 199th: the loss is 2.34557
# Iteration 200th: the loss is 2.23515
# Iteration 201th: the loss is 2.13023
# Iteration 202th: the loss is 2.03007
# Iteration 203th: the loss is 1.93475
# Iteration 204th: the loss is 1.84386
# Iteration 205th: the loss is 1.75739
# Iteration 206th: the loss is 1.6749
# Iteration 207th: the loss is 1.59653
# Iteration 208th: the loss is 1.52175
# Iteration 209th: the loss is 1.45052
# Iteration 210th: the loss is 1.38256
# Iteration 211th: the loss is 1.31793
# Iteration 212th: the loss is 1.2563
# Iteration 213th: the loss is 1.19769
# Iteration 214th: the loss is 1.14176
# Iteration 215th: the loss is 1.08848
# Iteration 216th: the loss is 1.03761
# Iteration 217th: the loss is 0.989273
# Iteration 218th: the loss is 0.94317
# Iteration 219th: the loss is 0.899198
# Iteration 220th: the loss is 0.857317
# Iteration 221th: the loss is 0.817419
# Iteration 222th: the loss is 0.77939
# Iteration 223th: the loss is 0.743077
# Iteration 224th: the loss is 0.708608
# Iteration 225th: the loss is 0.675658
# Iteration 226th: the loss is 0.644275
# Iteration 227th: the loss is 0.614371
# Iteration 228th: the loss is 0.585879
# Iteration 229th: the loss is 0.558614
# Iteration 230th: the loss is 0.532676
# Iteration 231th: the loss is 0.508027
# Iteration 232th: the loss is 0.484511
# Iteration 233th: the loss is 0.462054
# Iteration 234th: the loss is 0.440649
# Iteration 235th: the loss is 0.42028
# Iteration 236th: the loss is 0.400839
# Iteration 237th: the loss is 0.382307
# Iteration 238th: the loss is 0.36463
# Iteration 239th: the loss is 0.347764
# Iteration 240th: the loss is 0.331718
# Iteration 241th: the loss is 0.31642
# Iteration 242th: the loss is 0.301811
# Iteration 243th: the loss is 0.287865
# Iteration 244th: the loss is 0.27456
# Iteration 245th: the loss is 0.26192
# Iteration 246th: the loss is 0.24984
# Iteration 247th: the loss is 0.23831
# Iteration 248th: the loss is 0.227369
# Iteration 249th: the loss is 0.216868
# Iteration 250th: the loss is 0.206877
# Iteration 251th: the loss is 0.197338
# Iteration 252th: the loss is 0.188298
# Iteration 253th: the loss is 0.179628
# Iteration 254th: the loss is 0.171372
# Iteration 255th: the loss is 0.163494
# Iteration 256th: the loss is 0.155985
# Iteration 257th: the loss is 0.148824
# Iteration 258th: the loss is 0.141975
# Iteration 259th: the loss is 0.135459
# Iteration 260th: the loss is 0.129245
# Iteration 261th: the loss is 0.123302
# Iteration 262th: the loss is 0.117645
# Iteration 263th: the loss is 0.112255
# Iteration 264th: the loss is 0.107123
# Iteration 265th: the loss is 0.102223
# Iteration 266th: the loss is 0.0975325
# Iteration 267th: the loss is 0.0930788
# Iteration 268th: the loss is 0.0888211
# Iteration 269th: the loss is 0.0847466
# Iteration 270th: the loss is 0.0808633
# Iteration 271th: the loss is 0.0771784
# Iteration 272th: the loss is 0.0736534
# Iteration 273th: the loss is 0.0702789
# Iteration 274th: the loss is 0.0670848
# Iteration 275th: the loss is 0.0640167
# Iteration 276th: the loss is 0.0610991
# Iteration 277th: the loss is 0.0583176
# Iteration 278th: the loss is 0.0556593
# Iteration 279th: the loss is 0.0531182
# Iteration 280th: the loss is 0.050712
# Iteration 281th: the loss is 0.0483988
# Iteration 282th: the loss is 0.0462005
# Iteration 283th: the loss is 0.0441002
# Iteration 284th: the loss is 0.0420816
# Iteration 285th: the loss is 0.040161
# Iteration 286th: the loss is 0.0383392
# Iteration 287th: the loss is 0.0365984
# Iteration 288th: the loss is 0.0349433
# Iteration 289th: the loss is 0.0333652
# Iteration 290th: the loss is 0.031863
# Iteration 291th: the loss is 0.0304169
# Iteration 292th: the loss is 0.0290341
# Iteration 293th: the loss is 0.0277268
# Iteration 294th: the loss is 0.026481
# Iteration 295th: the loss is 0.0252794
# Iteration 296th: the loss is 0.0241368
# Iteration 297th: the loss is 0.0230364
# Iteration 298th: the loss is 0.0220089
# Iteration 299th: the loss is 0.0210132
# Iteration 300th: the loss is 0.0200608
# Iteration 301th: the loss is 0.019159
# Iteration 302th: the loss is 0.0182951
# Iteration 303th: the loss is 0.0174809
# Iteration 304th: the loss is 0.0166946
# Iteration 305th: the loss is 0.0159494
# Iteration 306th: the loss is 0.0152367
# Iteration 307th: the loss is 0.0145554
# Iteration 308th: the loss is 0.0139112
# Iteration 309th: the loss is 0.0132883
# Iteration 310th: the loss is 0.0127026
# Iteration 311th: the loss is 0.012133
# Iteration 312th: the loss is 0.0116023
# Iteration 313th: the loss is 0.0110892
# Iteration 314th: the loss is 0.0105967
# Iteration 315th: the loss is 0.0101261
# Iteration 316th: the loss is 0.00967911
# Iteration 317th: the loss is 0.00925623
# Iteration 318th: the loss is 0.008849
# Iteration 319th: the loss is 0.00846349
# Iteration 320th: the loss is 0.00809325
# Iteration 321th: the loss is 0.00774713
# Iteration 322th: the loss is 0.00741004
# Iteration 323th: the loss is 0.00708482
# Iteration 324th: the loss is 0.00677798
# Iteration 325th: the loss is 0.00648984
# Iteration 326th: the loss is 0.0062084
# Iteration 327th: the loss is 0.00594004
# Iteration 328th: the loss is 0.00568513
# Iteration 329th: the loss is 0.0054427
# Iteration 330th: the loss is 0.0052148
# Iteration 331th: the loss is 0.00499167
# Iteration 332th: the loss is 0.00478122
# Iteration 333th: the loss is 0.00457983
# Iteration 334th: the loss is 0.00438425
# Iteration 335th: the loss is 0.00420082
# Iteration 336th: the loss is 0.00402088
# Iteration 337th: the loss is 0.00385536
# Iteration 338th: the loss is 0.00369365
# Iteration 339th: the loss is 0.003541
# Iteration 340th: the loss is 0.00339648
# Iteration 341th: the loss is 0.00325588
# Iteration 342th: the loss is 0.00312562
# Iteration 343th: the loss is 0.00299736
# Iteration 344th: the loss is 0.00287562
# Iteration 345th: the loss is 0.00275953
# Iteration 346th: the loss is 0.00264764
# Iteration 347th: the loss is 0.00254055
# Iteration 348th: the loss is 0.00244003
# Iteration 349th: the loss is 0.00234414
# Iteration 350th: the loss is 0.00225141
# Iteration 351th: the loss is 0.00216482
# Iteration 352th: the loss is 0.00207677
# Iteration 353th: the loss is 0.00199719
# Iteration 354th: the loss is 0.00192097
# Iteration 355th: the loss is 0.00184366
# Iteration 356th: the loss is 0.0017748
# Iteration 357th: the loss is 0.00170758
# Iteration 358th: the loss is 0.00164318
# Iteration 359th: the loss is 0.00158176
# Iteration 360th: the loss is 0.00152145
# Iteration 361th: the loss is 0.00146411
# Iteration 362th: the loss is 0.00141104
# Iteration 363th: the loss is 0.00135817
# Iteration 364th: the loss is 0.00130901
# Iteration 365th: the loss is 0.00126232
# Iteration 366th: the loss is 0.00121487
# Iteration 367th: the loss is 0.00117295
# Iteration 368th: the loss is 0.00113029
# Iteration 369th: the loss is 0.00109059
# Iteration 370th: the loss is 0.00105171
# Iteration 371th: the loss is 0.00101467
# Iteration 372th: the loss is 0.000980945
# Iteration 373th: the loss is 0.000946543
# Iteration 374th: the loss is 0.00091263
# Iteration 375th: the loss is 0.00088269
# Iteration 376th: the loss is 0.000853141
# Iteration 377th: the loss is 0.000825767
# Iteration 378th: the loss is 0.00079679
# Iteration 379th: the loss is 0.00077072
# Iteration 380th: the loss is 0.000745159
# Iteration 381th: the loss is 0.000720488
# Iteration 382th: the loss is 0.000697429
# Iteration 383th: the loss is 0.000674568
# Iteration 384th: the loss is 0.000653833
# Iteration 385th: the loss is 0.000632025
# Iteration 386th: the loss is 0.000612477
# Iteration 387th: the loss is 0.000592602
# Iteration 388th: the loss is 0.00057453
# Iteration 389th: the loss is 0.000555874
# Iteration 390th: the loss is 0.000539193
# Iteration 391th: the loss is 0.000523111
# Iteration 392th: the loss is 0.000507312
# Iteration 393th: the loss is 0.000491421
# Iteration 394th: the loss is 0.000476249
# Iteration 395th: the loss is 0.000462298
# Iteration 396th: the loss is 0.000448742
# Iteration 397th: the loss is 0.000435637
# Iteration 398th: the loss is 0.000423152
# Iteration 399th: the loss is 0.000410717
# Iteration 400th: the loss is 0.000398213
# Iteration 401th: the loss is 0.000386469
# Iteration 402th: the loss is 0.0003764
# Iteration 403th: the loss is 0.000364852
# Iteration 404th: the loss is 0.000354764
# Iteration 405th: the loss is 0.000345611
# Iteration 406th: the loss is 0.000335747
# Iteration 407th: the loss is 0.000326061
# Iteration 408th: the loss is 0.000316875
# Iteration 409th: the loss is 0.000308497
# Iteration 410th: the loss is 0.000299828
# Iteration 411th: the loss is 0.000291548
# Iteration 412th: the loss is 0.000283812
# Iteration 413th: the loss is 0.000277132
# Iteration 414th: the loss is 0.000269833
# Iteration 415th: the loss is 0.000262605
# Iteration 416th: the loss is 0.000255417
# Iteration 417th: the loss is 0.000249576
# Iteration 418th: the loss is 0.000242297
# Iteration 419th: the loss is 0.000236397
# Iteration 420th: the loss is 0.000230301
# Iteration 421th: the loss is 0.000224431
# Iteration 422th: the loss is 0.000218749
# Iteration 423th: the loss is 0.000212456
# Iteration 424th: the loss is 0.000207602
# Iteration 425th: the loss is 0.000202572
# Iteration 426th: the loss is 0.000197653
# Iteration 427th: the loss is 0.000192817
# Iteration 428th: the loss is 0.000188127
# Iteration 429th: the loss is 0.000183782
# Iteration 430th: the loss is 0.000179701
# Iteration 431th: the loss is 0.00017504
# Iteration 432th: the loss is 0.000171167
# Iteration 433th: the loss is 0.000167426
# Iteration 434th: the loss is 0.000163253
# Iteration 435th: the loss is 0.000159384
# Iteration 436th: the loss is 0.000155829
# Iteration 437th: the loss is 0.000152512
# Iteration 438th: the loss is 0.000148445
# Iteration 439th: the loss is 0.000145251
# Iteration 440th: the loss is 0.000142135
# Iteration 441th: the loss is 0.000138962
# Iteration 442th: the loss is 0.000135983
# Iteration 443th: the loss is 0.000133148
# Iteration 444th: the loss is 0.000130134
# Iteration 445th: the loss is 0.000127352
# Iteration 446th: the loss is 0.000124386
# Iteration 447th: the loss is 0.000121852
# Iteration 448th: the loss is 0.000119243
# Iteration 449th: the loss is 0.000116759
# Iteration 450th: the loss is 0.000114106
# Iteration 451th: the loss is 0.000112301
# Iteration 452th: the loss is 0.000109745
# Iteration 453th: the loss is 0.000107136
# Iteration 454th: the loss is 0.000105189
# Iteration 455th: the loss is 0.000102891
# Iteration 456th: the loss is 0.000100805
# Iteration 457th: the loss is 9.88376e-05
# Iteration 458th: the loss is 9.70088e-05
# Iteration 459th: the loss is 9.49503e-05
# Iteration 460th: the loss is 9.34274e-05
# Iteration 461th: the loss is 9.17321e-05
# Iteration 462th: the loss is 8.97384e-05
# Iteration 463th: the loss is 8.79212e-05
# Iteration 464th: the loss is 8.6308e-05
# Iteration 465th: the loss is 8.42522e-05
# Iteration 466th: the loss is 8.26789e-05
# Iteration 467th: the loss is 8.13298e-05
# Iteration 468th: the loss is 7.98659e-05
# Iteration 469th: the loss is 7.83475e-05
# Iteration 470th: the loss is 7.66766e-05
# Iteration 471th: the loss is 7.51907e-05
# Iteration 472th: the loss is 7.39609e-05
# Iteration 473th: the loss is 7.26931e-05
# Iteration 474th: the loss is 7.12735e-05
# Iteration 475th: the loss is 7.02113e-05
# Iteration 476th: the loss is 6.90185e-05
# Iteration 477th: the loss is 6.79455e-05
# Iteration 478th: the loss is 6.65925e-05
# Iteration 479th: the loss is 6.5478e-05
# Iteration 480th: the loss is 6.4398e-05
# Iteration 481th: the loss is 6.3261e-05
# Iteration 482th: the loss is 6.23227e-05
# Iteration 483th: the loss is 6.13494e-05
# Iteration 484th: the loss is 6.01399e-05
# Iteration 485th: the loss is 5.90279e-05
# Iteration 486th: the loss is 5.80812e-05
# Iteration 487th: the loss is 5.71674e-05
# Iteration 488th: the loss is 5.61389e-05
# Iteration 489th: the loss is 5.49206e-05
# Iteration 490th: the loss is 5.40871e-05
# Iteration 491th: the loss is 5.32122e-05
# Iteration 492th: the loss is 5.26798e-05
# Iteration 493th: the loss is 5.1847e-05
# Iteration 494th: the loss is 5.11979e-05
# Iteration 495th: the loss is 5.0287e-05
# Iteration 496th: the loss is 4.94503e-05
# Iteration 497th: the loss is 4.86616e-05
# Iteration 498th: the loss is 4.78682e-05
# Iteration 499th: the loss is 4.72775e-05

# %%
import torch
from torch.autograd import Variable

N, D_in, H, D_out = 64, 1000, 100, 10

x = Variable(torch.randn(N, D_in), requires_grad=False)
y = Variable(torch.randn(N, D_out), requires_grad=False)

w1 = Variable(torch.randn(D_in, H), requires_grad=True)
w2 = Variable(torch.randn(H, D_out), requires_grad=True)

learning_rate = 1e-6

for i in range(500):
    h = x.mm(w1)
    h_relu = h.clamp(min=0)
    y_pred = h_relu.mm(w2)
    
    loss = (y_pred - y).pow(2).sum()
    loss.backward()

    w1.data -= learning_rate * w1.grad.data
    w2.data -= learning_rate * w2.grad.data

    w1.grad.data.zero_()
    w2.grad.data.zero_()
    
    print("Iteration " + str(i) + "th: the loss is " + str(loss))
# Out:
# Iteration 0th: the loss is Variable containing:
#  3.0351e+07
# [torch.FloatTensor of size 1]
#
# Iteration 1th: the loss is Variable containing:
#  2.3290e+07
# [torch.FloatTensor of size 1]
#
# Iteration 2th: the loss is Variable containing:
#  2.0736e+07
# [torch.FloatTensor of size 1]
#
# Iteration 3th: the loss is Variable containing:
#  1.9158e+07
# [torch.FloatTensor of size 1]
#
# Iteration 4th: the loss is Variable containing:
#  1.7107e+07
# [torch.FloatTensor of size 1]
#
# Iteration 5th: the loss is Variable containing:
#  1.4143e+07
# [torch.FloatTensor of size 1]
#
# Iteration 6th: the loss is Variable containing:
#  1.0756e+07
# [torch.FloatTensor of size 1]
#
# Iteration 7th: the loss is Variable containing:
#  7.5778e+06
# [torch.FloatTensor of size 1]
#
# Iteration 8th: the loss is Variable containing:
#  5.1011e+06
# [torch.FloatTensor of size 1]
#
# Iteration 9th: the loss is Variable containing:
# 1.00000e+06 *
#   3.3720
# [torch.FloatTensor of size 1]
#
# Iteration 10th: the loss is Variable containing:
# 1.00000e+06 *
#   2.2544
# [torch.FloatTensor of size 1]
#
# Iteration 11th: the loss is Variable containing:
# 1.00000e+06 *
#   1.5508
# [torch.FloatTensor of size 1]
#
# Iteration 12th: the loss is Variable containing:
# 1.00000e+06 *
#   1.1109
# [torch.FloatTensor of size 1]
#
# Iteration 13th: the loss is Variable containing:
# 1.00000e+05 *
#   8.3007
# [torch.FloatTensor of size 1]
#
# Iteration 14th: the loss is Variable containing:
# 1.00000e+05 *
#   6.4527
# [torch.FloatTensor of size 1]
#
# Iteration 15th: the loss is Variable containing:
# 1.00000e+05 *
#   5.1833
# [torch.FloatTensor of size 1]
#
# Iteration 16th: the loss is Variable containing:
# 1.00000e+05 *
#   4.2736
# [torch.FloatTensor of size 1]
#
# Iteration 17th: the loss is Variable containing:
# 1.00000e+05 *
#   3.5942
# [torch.FloatTensor of size 1]
#
# Iteration 18th: the loss is Variable containing:
# 1.00000e+05 *
#   3.0674
# [torch.FloatTensor of size 1]
#
# Iteration 19th: the loss is Variable containing:
# 1.00000e+05 *
#   2.6461
# [torch.FloatTensor of size 1]
#
# Iteration 20th: the loss is Variable containing:
# 1.00000e+05 *
#   2.3007
# [torch.FloatTensor of size 1]
#
# Iteration 21th: the loss is Variable containing:
# 1.00000e+05 *
#   2.0128
# [torch.FloatTensor of size 1]
#
# Iteration 22th: the loss is Variable containing:
# 1.00000e+05 *
#   1.7695
# [torch.FloatTensor of size 1]
#
# Iteration 23th: the loss is Variable containing:
# 1.00000e+05 *
#   1.5616
# [torch.FloatTensor of size 1]
#
# Iteration 24th: the loss is Variable containing:
# 1.00000e+05 *
#   1.3827
# [torch.FloatTensor of size 1]
#
# Iteration 25th: the loss is Variable containing:
# 1.00000e+05 *
#   1.2274
# [torch.FloatTensor of size 1]
#
# Iteration 26th: the loss is Variable containing:
# 1.00000e+05 *
#   1.0922
# [torch.FloatTensor of size 1]
#
# Iteration 27th: the loss is Variable containing:
#  97398.7422
# [torch.FloatTensor of size 1]
#
# Iteration 28th: the loss is Variable containing:
#  87025.6719
# [torch.FloatTensor of size 1]
#
# Iteration 29th: the loss is Variable containing:
#  77891.4922
# [torch.FloatTensor of size 1]
#
# Iteration 30th: the loss is Variable containing:
#  69797.3203
# [torch.FloatTensor of size 1]
#
# Iteration 31th: the loss is Variable containing:
#  62646.0234
# [torch.FloatTensor of size 1]
#
# Iteration 32th: the loss is Variable containing:
#  56314.5742
# [torch.FloatTensor of size 1]
#
# Iteration 33th: the loss is Variable containing:
#  50695.9219
# [torch.FloatTensor of size 1]
#
# Iteration 34th: the loss is Variable containing:
#  45698.8477
# [torch.FloatTensor of size 1]
#
# Iteration 35th: the loss is Variable containing:
#  41243.1602
# [torch.FloatTensor of size 1]
#
# Iteration 36th: the loss is Variable containing:
#  37264.6328
# [torch.FloatTensor of size 1]
#
# Iteration 37th: the loss is Variable containing:
#  33708.2227
# [torch.FloatTensor of size 1]
#
# Iteration 38th: the loss is Variable containing:
#  30521.9629
# [torch.FloatTensor of size 1]
#
# Iteration 39th: the loss is Variable containing:
#  27667.9180
# [torch.FloatTensor of size 1]
#
# Iteration 40th: the loss is Variable containing:
#  25106.5273
# [torch.FloatTensor of size 1]
#
# Iteration 41th: the loss is Variable containing:
#  22803.6406
# [torch.FloatTensor of size 1]
#
# Iteration 42th: the loss is Variable containing:
#  20730.0547
# [torch.FloatTensor of size 1]
#
# Iteration 43th: the loss is Variable containing:
#  18861.2852
# [torch.FloatTensor of size 1]
#
# Iteration 44th: the loss is Variable containing:
#  17175.5840
# [torch.FloatTensor of size 1]
#
# Iteration 45th: the loss is Variable containing:
#  15652.1348
# [torch.FloatTensor of size 1]
#
# Iteration 46th: the loss is Variable containing:
#  14275.0557
# [torch.FloatTensor of size 1]
#
# Iteration 47th: the loss is Variable containing:
#  13028.7109
# [torch.FloatTensor of size 1]
#
# Iteration 48th: the loss is Variable containing:
#  11899.7012
# [torch.FloatTensor of size 1]
#
# Iteration 49th: the loss is Variable containing:
#  10876.0430
# [torch.FloatTensor of size 1]
#
# Iteration 50th: the loss is Variable containing:
#  9947.4941
# [torch.FloatTensor of size 1]
#
# Iteration 51th: the loss is Variable containing:
#  9103.9785
# [torch.FloatTensor of size 1]
#
# Iteration 52th: the loss is Variable containing:
#  8337.4854
# [torch.FloatTensor of size 1]
#
# Iteration 53th: the loss is Variable containing:
#  7640.5874
# [torch.FloatTensor of size 1]
#
# Iteration 54th: the loss is Variable containing:
#  7006.0273
# [torch.FloatTensor of size 1]
#
# Iteration 55th: the loss is Variable containing:
#  6427.9243
# [torch.FloatTensor of size 1]
#
# Iteration 56th: the loss is Variable containing:
#  5901.5273
# [torch.FloatTensor of size 1]
#
# Iteration 57th: the loss is Variable containing:
#  5422.0166
# [torch.FloatTensor of size 1]
#
# Iteration 58th: the loss is Variable containing:
#  4984.1753
# [torch.FloatTensor of size 1]
#
# Iteration 59th: the loss is Variable containing:
#  4584.3149
# [torch.FloatTensor of size 1]
#
# Iteration 60th: the loss is Variable containing:
#  4218.6719
# [torch.FloatTensor of size 1]
#
# Iteration 61th: the loss is Variable containing:
#  3884.3203
# [torch.FloatTensor of size 1]
#
# Iteration 62th: the loss is Variable containing:
#  3578.3757
# [torch.FloatTensor of size 1]
#
# Iteration 63th: the loss is Variable containing:
#  3298.2151
# [torch.FloatTensor of size 1]
#
# Iteration 64th: the loss is Variable containing:
#  3041.6287
# [torch.FloatTensor of size 1]
#
# Iteration 65th: the loss is Variable containing:
#  2806.3364
# [torch.FloatTensor of size 1]
#
# Iteration 66th: the loss is Variable containing:
#  2590.3779
# [torch.FloatTensor of size 1]
#
# Iteration 67th: the loss is Variable containing:
#  2392.2678
# [torch.FloatTensor of size 1]
#
# Iteration 68th: the loss is Variable containing:
#  2210.2693
# [torch.FloatTensor of size 1]
#
# Iteration 69th: the loss is Variable containing:
#  2043.0353
# [torch.FloatTensor of size 1]
#
# Iteration 70th: the loss is Variable containing:
#  1889.2904
# [torch.FloatTensor of size 1]
#
# Iteration 71th: the loss is Variable containing:
#  1747.9364
# [torch.FloatTensor of size 1]
#
# Iteration 72th: the loss is Variable containing:
#  1617.8314
# [torch.FloatTensor of size 1]
#
# Iteration 73th: the loss is Variable containing:
#  1498.0822
# [torch.FloatTensor of size 1]
#
# Iteration 74th: the loss is Variable containing:
#  1387.7344
# [torch.FloatTensor of size 1]
#
# Iteration 75th: the loss is Variable containing:
#  1286.0696
# [torch.FloatTensor of size 1]
#
# Iteration 76th: the loss is Variable containing:
#  1192.3270
# [torch.FloatTensor of size 1]
#
# Iteration 77th: the loss is Variable containing:
#  1105.8616
# [torch.FloatTensor of size 1]
#
# Iteration 78th: the loss is Variable containing:
#  1026.1317
# [torch.FloatTensor of size 1]
#
# Iteration 79th: the loss is Variable containing:
#  952.4865
# [torch.FloatTensor of size 1]
#
# Iteration 80th: the loss is Variable containing:
#  884.4770
# [torch.FloatTensor of size 1]
#
# Iteration 81th: the loss is Variable containing:
#  821.6212
# [torch.FloatTensor of size 1]
#
# Iteration 82th: the loss is Variable containing:
#  763.5402
# [torch.FloatTensor of size 1]
#
# Iteration 83th: the loss is Variable containing:
#  709.8322
# [torch.FloatTensor of size 1]
#
# Iteration 84th: the loss is Variable containing:
#  660.1423
# [torch.FloatTensor of size 1]
#
# Iteration 85th: the loss is Variable containing:
#  614.1543
# [torch.FloatTensor of size 1]
#
# Iteration 86th: the loss is Variable containing:
#  571.6030
# [torch.FloatTensor of size 1]
#
# Iteration 87th: the loss is Variable containing:
#  532.2047
# [torch.FloatTensor of size 1]
#
# Iteration 88th: the loss is Variable containing:
#  495.6954
# [torch.FloatTensor of size 1]
#
# Iteration 89th: the loss is Variable containing:
#  461.8508
# [torch.FloatTensor of size 1]
#
# Iteration 90th: the loss is Variable containing:
#  430.4790
# [torch.FloatTensor of size 1]
#
# Iteration 91th: the loss is Variable containing:
#  401.3778
# [torch.FloatTensor of size 1]
#
# Iteration 92th: the loss is Variable containing:
#  374.3613
# [torch.FloatTensor of size 1]
#
# Iteration 93th: the loss is Variable containing:
#  349.2836
# [torch.FloatTensor of size 1]
#
# Iteration 94th: the loss is Variable containing:
#  325.9931
# [torch.FloatTensor of size 1]
#
# Iteration 95th: the loss is Variable containing:
#  304.3497
# [torch.FloatTensor of size 1]
#
# Iteration 96th: the loss is Variable containing:
#  284.2355
# [torch.FloatTensor of size 1]
#
# Iteration 97th: the loss is Variable containing:
#  265.5325
# [torch.FloatTensor of size 1]
#
# Iteration 98th: the loss is Variable containing:
#  248.1473
# [torch.FloatTensor of size 1]
#
# Iteration 99th: the loss is Variable containing:
#  231.9624
# [torch.FloatTensor of size 1]
#
# Iteration 100th: the loss is Variable containing:
#  216.9011
# [torch.FloatTensor of size 1]
#
# Iteration 101th: the loss is Variable containing:
#  202.8774
# [torch.FloatTensor of size 1]
#
# Iteration 102th: the loss is Variable containing:
#  189.8237
# [torch.FloatTensor of size 1]
#
# Iteration 103th: the loss is Variable containing:
#  177.6602
# [torch.FloatTensor of size 1]
#
# Iteration 104th: the loss is Variable containing:
#  166.3228
# [torch.FloatTensor of size 1]
#
# Iteration 105th: the loss is Variable containing:
#  155.7554
# [torch.FloatTensor of size 1]
#
# Iteration 106th: the loss is Variable containing:
#  145.9004
# [torch.FloatTensor of size 1]
#
# Iteration 107th: the loss is Variable containing:
#  136.7101
# [torch.FloatTensor of size 1]
#
# Iteration 108th: the loss is Variable containing:
#  128.1329
# [torch.FloatTensor of size 1]
#
# Iteration 109th: the loss is Variable containing:
#  120.1258
# [torch.FloatTensor of size 1]
#
# Iteration 110th: the loss is Variable containing:
#  112.6528
# [torch.FloatTensor of size 1]
#
# Iteration 111th: the loss is Variable containing:
#  105.6699
# [torch.FloatTensor of size 1]
#
# Iteration 112th: the loss is Variable containing:
#  99.1479
# [torch.FloatTensor of size 1]
#
# Iteration 113th: the loss is Variable containing:
#  93.0518
# [torch.FloatTensor of size 1]
#
# Iteration 114th: the loss is Variable containing:
#  87.3536
# [torch.FloatTensor of size 1]
#
# Iteration 115th: the loss is Variable containing:
#  82.0293
# [torch.FloatTensor of size 1]
#
# Iteration 116th: the loss is Variable containing:
#  77.0465
# [torch.FloatTensor of size 1]
#
# Iteration 117th: the loss is Variable containing:
#  72.3843
# [torch.FloatTensor of size 1]
#
# Iteration 118th: the loss is Variable containing:
#  68.0203
# [torch.FloatTensor of size 1]
#
# Iteration 119th: the loss is Variable containing:
#  63.9375
# [torch.FloatTensor of size 1]
#
# Iteration 120th: the loss is Variable containing:
#  60.1134
# [torch.FloatTensor of size 1]
#
# Iteration 121th: the loss is Variable containing:
#  56.5308
# [torch.FloatTensor of size 1]
# Iteration 122th: the loss is Variable containing:
#  53.1746
# [torch.FloatTensor of size 1]
#
# Iteration 123th: the loss is Variable containing:
#  50.0298
# [torch.FloatTensor of size 1]
#
# Iteration 124th: the loss is Variable containing:
#  47.0818
# [torch.FloatTensor of size 1]
#
# Iteration 125th: the loss is Variable containing:
#  44.3189
# [torch.FloatTensor of size 1]
#
# Iteration 126th: the loss is Variable containing:
#  41.7269
# [torch.FloatTensor of size 1]
#
# Iteration 127th: the loss is Variable containing:
#  39.2963
# [torch.FloatTensor of size 1]
#
# Iteration 128th: the loss is Variable containing:
#  37.0145
# [torch.FloatTensor of size 1]
#
# Iteration 129th: the loss is Variable containing:
#  34.8742
# [torch.FloatTensor of size 1]
#
# Iteration 130th: the loss is Variable containing:
#  32.8632
# [torch.FloatTensor of size 1]
#
# Iteration 131th: the loss is Variable containing:
#  30.9750
# [torch.FloatTensor of size 1]
#
# Iteration 132th: the loss is Variable containing:
#  29.2015
# [torch.FloatTensor of size 1]
#
# Iteration 133th: the loss is Variable containing:
#  27.5357
# [torch.FloatTensor of size 1]
#
# Iteration 134th: the loss is Variable containing:
#  25.9697
# [torch.FloatTensor of size 1]
#
# Iteration 135th: the loss is Variable containing:
#  24.4978
# [torch.FloatTensor of size 1]
#
# Iteration 136th: the loss is Variable containing:
#  23.1138
# [torch.FloatTensor of size 1]
#
# Iteration 137th: the loss is Variable containing:
#  21.8123
# [torch.FloatTensor of size 1]
#
# Iteration 138th: the loss is Variable containing:
#  20.5877
# [torch.FloatTensor of size 1]
#
# Iteration 139th: the loss is Variable containing:
#  19.4360
# [torch.FloatTensor of size 1]
#
# Iteration 140th: the loss is Variable containing:
#  18.3520
# [torch.FloatTensor of size 1]
#
# Iteration 141th: the loss is Variable containing:
#  17.3310
# [torch.FloatTensor of size 1]
#
# Iteration 142th: the loss is Variable containing:
#  16.3708
# [torch.FloatTensor of size 1]
#
# Iteration 143th: the loss is Variable containing:
#  15.4653
# [torch.FloatTensor of size 1]
#
# Iteration 144th: the loss is Variable containing:
#  14.6129
# [torch.FloatTensor of size 1]
#
# Iteration 145th: the loss is Variable containing:
#  13.8101
# [torch.FloatTensor of size 1]
#
# Iteration 146th: the loss is Variable containing:
#  13.0535
# [torch.FloatTensor of size 1]
#
# Iteration 147th: the loss is Variable containing:
#  12.3404
# [torch.FloatTensor of size 1]
#
# Iteration 148th: the loss is Variable containing:
#  11.6681
# [torch.FloatTensor of size 1]
#
# Iteration 149th: the loss is Variable containing:
#  11.0341
# [torch.FloatTensor of size 1]
#
# Iteration 150th: the loss is Variable containing:
#  10.4370
# [torch.FloatTensor of size 1]
#
# Iteration 151th: the loss is Variable containing:
#  9.8730
# [torch.FloatTensor of size 1]
#
# Iteration 152th: the loss is Variable containing:
#  9.3409
# [torch.FloatTensor of size 1]
#
# Iteration 153th: the loss is Variable containing:
#  8.8386
# [torch.FloatTensor of size 1]
#
# Iteration 154th: the loss is Variable containing:
#  8.3656
# [torch.FloatTensor of size 1]
#
# Iteration 155th: the loss is Variable containing:
#  7.9186
# [torch.FloatTensor of size 1]
#
# Iteration 156th: the loss is Variable containing:
#  7.4961
# [torch.FloatTensor of size 1]
#
# Iteration 157th: the loss is Variable containing:
#  7.0973
# [torch.FloatTensor of size 1]
#
# Iteration 158th: the loss is Variable containing:
#  6.7206
# [torch.FloatTensor of size 1]
#
# Iteration 159th: the loss is Variable containing:
#  6.3653
# [torch.FloatTensor of size 1]
#
# Iteration 160th: the loss is Variable containing:
#  6.0289
# [torch.FloatTensor of size 1]
#
# Iteration 161th: the loss is Variable containing:
#  5.7115
# [torch.FloatTensor of size 1]
#
# Iteration 162th: the loss is Variable containing:
#  5.4115
# [torch.FloatTensor of size 1]
#
# Iteration 163th: the loss is Variable containing:
#  5.1278
# [torch.FloatTensor of size 1]
#
# Iteration 164th: the loss is Variable containing:
#  4.8598
# [torch.FloatTensor of size 1]
#
# Iteration 165th: the loss is Variable containing:
#  4.6060
# [torch.FloatTensor of size 1]
#
# Iteration 166th: the loss is Variable containing:
#  4.3663
# [torch.FloatTensor of size 1]
#
# Iteration 167th: the loss is Variable containing:
#  4.1395
# [torch.FloatTensor of size 1]
#
# Iteration 168th: the loss is Variable containing:
#  3.9247
# [torch.FloatTensor of size 1]
#
# Iteration 169th: the loss is Variable containing:
#  3.7216
# [torch.FloatTensor of size 1]
#
# Iteration 170th: the loss is Variable containing:
#  3.5296
# [torch.FloatTensor of size 1]
#
# Iteration 171th: the loss is Variable containing:
#  3.3477
# [torch.FloatTensor of size 1]
#
# Iteration 172th: the loss is Variable containing:
#  3.1754
# [torch.FloatTensor of size 1]
#
# Iteration 173th: the loss is Variable containing:
#  3.0127
# [torch.FloatTensor of size 1]
#
# Iteration 174th: the loss is Variable containing:
#  2.8582
# [torch.FloatTensor of size 1]
#
# Iteration 175th: the loss is Variable containing:
#  2.7122
# [torch.FloatTensor of size 1]
#
# Iteration 176th: the loss is Variable containing:
#  2.5739
# [torch.FloatTensor of size 1]
#
# Iteration 177th: the loss is Variable containing:
#  2.4428
# [torch.FloatTensor of size 1]
#
# Iteration 178th: the loss is Variable containing:
#  2.3187
# [torch.FloatTensor of size 1]
#
# Iteration 179th: the loss is Variable containing:
#  2.2009
# [torch.FloatTensor of size 1]
#
# Iteration 180th: the loss is Variable containing:
#  2.0896
# [torch.FloatTensor of size 1]
#
# Iteration 181th: the loss is Variable containing:
#  1.9840
# [torch.FloatTensor of size 1]
#
# Iteration 182th: the loss is Variable containing:
#  1.8839
# [torch.FloatTensor of size 1]
#
# Iteration 183th: the loss is Variable containing:
#  1.7887
# [torch.FloatTensor of size 1]
#
# Iteration 184th: the loss is Variable containing:
#  1.6989
# [torch.FloatTensor of size 1]
#
# Iteration 185th: the loss is Variable containing:
#  1.6135
# [torch.FloatTensor of size 1]
#
# Iteration 186th: the loss is Variable containing:
#  1.5326
# [torch.FloatTensor of size 1]
#
# Iteration 187th: the loss is Variable containing:
#  1.4560
# [torch.FloatTensor of size 1]
#
# Iteration 188th: the loss is Variable containing:
#  1.3831
# [torch.FloatTensor of size 1]
#
# Iteration 189th: the loss is Variable containing:
#  1.3141
# [torch.FloatTensor of size 1]
#
# Iteration 190th: the loss is Variable containing:
#  1.2487
# [torch.FloatTensor of size 1]
#
# Iteration 191th: the loss is Variable containing:
#  1.1864
# [torch.FloatTensor of size 1]
#
# Iteration 192th: the loss is Variable containing:
#  1.1275
# [torch.FloatTensor of size 1]
#
# Iteration 193th: the loss is Variable containing:
#  1.0715
# [torch.FloatTensor of size 1]
#
# Iteration 194th: the loss is Variable containing:
#  1.0185
# [torch.FloatTensor of size 1]
#
# Iteration 195th: the loss is Variable containing:
#  0.9681
# [torch.FloatTensor of size 1]
#
# Iteration 196th: the loss is Variable containing:
#  0.9203
# [torch.FloatTensor of size 1]
#
# Iteration 197th: the loss is Variable containing:
#  0.8749
# [torch.FloatTensor of size 1]
#
# Iteration 198th: the loss is Variable containing:
#  0.8317
# [torch.FloatTensor of size 1]
#
# Iteration 199th: the loss is Variable containing:
#  0.7909
# [torch.FloatTensor of size 1]
#
# Iteration 200th: the loss is Variable containing:
#  0.7519
# [torch.FloatTensor of size 1]
#
# Iteration 201th: the loss is Variable containing:
#  0.7151
# [torch.FloatTensor of size 1]
#
# Iteration 202th: the loss is Variable containing:
#  0.6800
# [torch.FloatTensor of size 1]
#
# Iteration 203th: the loss is Variable containing:
#  0.6467
# [torch.FloatTensor of size 1]
#
# Iteration 204th: the loss is Variable containing:
#  0.6151
# [torch.FloatTensor of size 1]
#
# Iteration 205th: the loss is Variable containing:
#  0.5851
# [torch.FloatTensor of size 1]
#
# Iteration 206th: the loss is Variable containing:
#  0.5564
# [torch.FloatTensor of size 1]
#
# Iteration 207th: the loss is Variable containing:
#  0.5294
# [torch.FloatTensor of size 1]
#
# Iteration 208th: the loss is Variable containing:
#  0.5036
# [torch.FloatTensor of size 1]
#
# Iteration 209th: the loss is Variable containing:
#  0.4791
# [torch.FloatTensor of size 1]
#
# Iteration 210th: the loss is Variable containing:
#  0.4558
# [torch.FloatTensor of size 1]
#
# Iteration 211th: the loss is Variable containing:
#  0.4337
# [torch.FloatTensor of size 1]
#
# Iteration 212th: the loss is Variable containing:
#  0.4126
# [torch.FloatTensor of size 1]
#
# Iteration 213th: the loss is Variable containing:
#  0.3926
# [torch.FloatTensor of size 1]
#
# Iteration 214th: the loss is Variable containing:
#  0.3736
# [torch.FloatTensor of size 1]
#
# Iteration 215th: the loss is Variable containing:
#  0.3556
# [torch.FloatTensor of size 1]
#
# Iteration 216th: the loss is Variable containing:
#  0.3384
# [torch.FloatTensor of size 1]
#
# Iteration 217th: the loss is Variable containing:
#  0.3221
# [torch.FloatTensor of size 1]
#
# Iteration 218th: the loss is Variable containing:
#  0.3066
# [torch.FloatTensor of size 1]
#
# Iteration 219th: the loss is Variable containing:
#  0.2919
# [torch.FloatTensor of size 1]
#
# Iteration 220th: the loss is Variable containing:
#  0.2778
# [torch.FloatTensor of size 1]
#
# Iteration 221th: the loss is Variable containing:
#  0.2644
# [torch.FloatTensor of size 1]
#
# Iteration 222th: the loss is Variable containing:
#  0.2517
# [torch.FloatTensor of size 1]
#
# Iteration 223th: the loss is Variable containing:
#  0.2396
# [torch.FloatTensor of size 1]
#
# Iteration 224th: the loss is Variable containing:
#  0.2282
# [torch.FloatTensor of size 1]
#
# Iteration 225th: the loss is Variable containing:
#  0.2172
# [torch.FloatTensor of size 1]
#
# Iteration 226th: the loss is Variable containing:
#  0.2068
# [torch.FloatTensor of size 1]
#
# Iteration 227th: the loss is Variable containing:
#  0.1969
# [torch.FloatTensor of size 1]
#
# Iteration 228th: the loss is Variable containing:
#  0.1875
# [torch.FloatTensor of size 1]
#
# Iteration 229th: the loss is Variable containing:
#  0.1786
# [torch.FloatTensor of size 1]
#
# Iteration 230th: the loss is Variable containing:
#  0.1700
# [torch.FloatTensor of size 1]
#
# Iteration 231th: the loss is Variable containing:
#  0.1619
# [torch.FloatTensor of size 1]
#
# Iteration 232th: the loss is Variable containing:
#  0.1542
# [torch.FloatTensor of size 1]
#
# Iteration 233th: the loss is Variable containing:
#  0.1468
# [torch.FloatTensor of size 1]
#
# Iteration 234th: the loss is Variable containing:
#  0.1399
# [torch.FloatTensor of size 1]
#
# Iteration 235th: the loss is Variable containing:
#  0.1332
# [torch.FloatTensor of size 1]
#
# Iteration 236th: the loss is Variable containing:
#  0.1269
# [torch.FloatTensor of size 1]
#
# Iteration 237th: the loss is Variable containing:
#  0.1209
# [torch.FloatTensor of size 1]
#
# Iteration 238th: the loss is Variable containing:
#  0.1151
# [torch.FloatTensor of size 1]
#
# Iteration 239th: the loss is Variable containing:
#  0.1097
# [torch.FloatTensor of size 1]
#
# Iteration 240th: the loss is Variable containing:
#  0.1045
# [torch.FloatTensor of size 1]
#
# Iteration 241th: the loss is Variable containing:
# 1.00000e-02 *
#   9.9517
# [torch.FloatTensor of size 1]
#
# Iteration 242th: the loss is Variable containing:
# 1.00000e-02 *
#   9.4819
# [torch.FloatTensor of size 1]
#
# Iteration 243th: the loss is Variable containing:
# 1.00000e-02 *
#   9.0304
# [torch.FloatTensor of size 1]
#
# Iteration 244th: the loss is Variable containing:
# 1.00000e-02 *
#   8.6059
# [torch.FloatTensor of size 1]
#
# Iteration 245th: the loss is Variable containing:
# 1.00000e-02 *
#   8.2023
# [torch.FloatTensor of size 1]
#
# Iteration 246th: the loss is Variable containing:
# 1.00000e-02 *
#   7.8131
# [torch.FloatTensor of size 1]
#
# Iteration 247th: the loss is Variable containing:
# 1.00000e-02 *
#   7.4455
# [torch.FloatTensor of size 1]
#
# Iteration 248th: the loss is Variable containing:
# 1.00000e-02 *
#   7.0962
# [torch.FloatTensor of size 1]
#
# Iteration 249th: the loss is Variable containing:
# 1.00000e-02 *
#   6.7625
# [torch.FloatTensor of size 1]
#
# Iteration 250th: the loss is Variable containing:
# 1.00000e-02 *
#   6.4420
# [torch.FloatTensor of size 1]
# Iteration 251th: the loss is Variable containing:
# 1.00000e-02 *
#   6.1374
# [torch.FloatTensor of size 1]
#
# Iteration 252th: the loss is Variable containing:
# 1.00000e-02 *
#   5.8501
# [torch.FloatTensor of size 1]
#
# Iteration 253th: the loss is Variable containing:
# 1.00000e-02 *
#   5.5734
# [torch.FloatTensor of size 1]
#
# Iteration 254th: the loss is Variable containing:
# 1.00000e-02 *
#   5.3146
# [torch.FloatTensor of size 1]
#
# Iteration 255th: the loss is Variable containing:
# 1.00000e-02 *
#   5.0639
# [torch.FloatTensor of size 1]
#
# Iteration 256th: the loss is Variable containing:
# 1.00000e-02 *
#   4.8271
# [torch.FloatTensor of size 1]
#
# Iteration 257th: the loss is Variable containing:
# 1.00000e-02 *
#   4.5994
# [torch.FloatTensor of size 1]
#
# Iteration 258th: the loss is Variable containing:
# 1.00000e-02 *
#   4.3853
# [torch.FloatTensor of size 1]
#
# Iteration 259th: the loss is Variable containing:
# 1.00000e-02 *
#   4.1792
# [torch.FloatTensor of size 1]
#
# Iteration 260th: the loss is Variable containing:
# 1.00000e-02 *
#   3.9842
# [torch.FloatTensor of size 1]
#
# Iteration 261th: the loss is Variable containing:
# 1.00000e-02 *
#   3.7968
# [torch.FloatTensor of size 1]
#
# Iteration 262th: the loss is Variable containing:
# 1.00000e-02 *
#   3.6204
# [torch.FloatTensor of size 1]
#
# Iteration 263th: the loss is Variable containing:
# 1.00000e-02 *
#   3.4525
# [torch.FloatTensor of size 1]
#
# Iteration 264th: the loss is Variable containing:
# 1.00000e-02 *
#   3.2896
# [torch.FloatTensor of size 1]
#
# Iteration 265th: the loss is Variable containing:
# 1.00000e-02 *
#   3.1373
# [torch.FloatTensor of size 1]
#
# Iteration 266th: the loss is Variable containing:
# 1.00000e-02 *
#   2.9906
# [torch.FloatTensor of size 1]
#
# Iteration 267th: the loss is Variable containing:
# 1.00000e-02 *
#   2.8517
# [torch.FloatTensor of size 1]
#
# Iteration 268th: the loss is Variable containing:
# 1.00000e-02 *
#   2.7194
# [torch.FloatTensor of size 1]
#
# Iteration 269th: the loss is Variable containing:
# 1.00000e-02 *
#   2.5935
# [torch.FloatTensor of size 1]
#
# Iteration 270th: the loss is Variable containing:
# 1.00000e-02 *
#   2.4723
# [torch.FloatTensor of size 1]
#
# Iteration 271th: the loss is Variable containing:
# 1.00000e-02 *
#   2.3577
# [torch.FloatTensor of size 1]
#
# Iteration 272th: the loss is Variable containing:
# 1.00000e-02 *
#   2.2484
# [torch.FloatTensor of size 1]
#
# Iteration 273th: the loss is Variable containing:
# 1.00000e-02 *
#   2.1440
# [torch.FloatTensor of size 1]
#
# Iteration 274th: the loss is Variable containing:
# 1.00000e-02 *
#   2.0450
# [torch.FloatTensor of size 1]
#
# Iteration 275th: the loss is Variable containing:
# 1.00000e-02 *
#   1.9506
# [torch.FloatTensor of size 1]
#
# Iteration 276th: the loss is Variable containing:
# 1.00000e-02 *
#   1.8624
# [torch.FloatTensor of size 1]
#
# Iteration 277th: the loss is Variable containing:
# 1.00000e-02 *
#   1.7768
# [torch.FloatTensor of size 1]
#
# Iteration 278th: the loss is Variable containing:
# 1.00000e-02 *
#   1.6946
# [torch.FloatTensor of size 1]
#
# Iteration 279th: the loss is Variable containing:
# 1.00000e-02 *
#   1.6166
# [torch.FloatTensor of size 1]
#
# Iteration 280th: the loss is Variable containing:
# 1.00000e-02 *
#   1.5426
# [torch.FloatTensor of size 1]
#
# Iteration 281th: the loss is Variable containing:
# 1.00000e-02 *
#   1.4724
# [torch.FloatTensor of size 1]
#
# Iteration 282th: the loss is Variable containing:
# 1.00000e-02 *
#   1.4054
# [torch.FloatTensor of size 1]
#
# Iteration 283th: the loss is Variable containing:
# 1.00000e-02 *
#   1.3411
# [torch.FloatTensor of size 1]
#
# Iteration 284th: the loss is Variable containing:
# 1.00000e-02 *
#   1.2799
# [torch.FloatTensor of size 1]
#
# Iteration 285th: the loss is Variable containing:
# 1.00000e-02 *
#   1.2202
# [torch.FloatTensor of size 1]
#
# Iteration 286th: the loss is Variable containing:
# 1.00000e-02 *
#   1.1658
# [torch.FloatTensor of size 1]
#
# Iteration 287th: the loss is Variable containing:
# 1.00000e-02 *
#   1.1130
# [torch.FloatTensor of size 1]
#
# Iteration 288th: the loss is Variable containing:
# 1.00000e-02 *
#   1.0617
# [torch.FloatTensor of size 1]
#
# Iteration 289th: the loss is Variable containing:
# 1.00000e-02 *
#   1.0141
# [torch.FloatTensor of size 1]
#
# Iteration 290th: the loss is Variable containing:
# 1.00000e-03 *
#   9.6793
# [torch.FloatTensor of size 1]
#
# Iteration 291th: the loss is Variable containing:
# 1.00000e-03 *
#   9.2419
# [torch.FloatTensor of size 1]
#
# Iteration 292th: the loss is Variable containing:
# 1.00000e-03 *
#   8.8268
# [torch.FloatTensor of size 1]
#
# Iteration 293th: the loss is Variable containing:
# 1.00000e-03 *
#   8.4290
# [torch.FloatTensor of size 1]
#
# Iteration 294th: the loss is Variable containing:
# 1.00000e-03 *
#   8.0442
# [torch.FloatTensor of size 1]
#
# Iteration 295th: the loss is Variable containing:
# 1.00000e-03 *
#   7.6886
# [torch.FloatTensor of size 1]
#
# Iteration 296th: the loss is Variable containing:
# 1.00000e-03 *
#   7.3395
# [torch.FloatTensor of size 1]
#
# Iteration 297th: the loss is Variable containing:
# 1.00000e-03 *
#   7.0122
# [torch.FloatTensor of size 1]
#
# Iteration 298th: the loss is Variable containing:
# 1.00000e-03 *
#   6.7041
# [torch.FloatTensor of size 1]
#
# Iteration 299th: the loss is Variable containing:
# 1.00000e-03 *
#   6.4058
# [torch.FloatTensor of size 1]
#
# Iteration 300th: the loss is Variable containing:
# 1.00000e-03 *
#   6.1270
# [torch.FloatTensor of size 1]
#
# Iteration 301th: the loss is Variable containing:
# 1.00000e-03 *
#   5.8582
# [torch.FloatTensor of size 1]
#
# Iteration 302th: the loss is Variable containing:
# 1.00000e-03 *
#   5.5979
# [torch.FloatTensor of size 1]
#
# Iteration 303th: the loss is Variable containing:
# 1.00000e-03 *
#   5.3510
# [torch.FloatTensor of size 1]
#
# Iteration 304th: the loss is Variable containing:
# 1.00000e-03 *
#   5.1134
# [torch.FloatTensor of size 1]
#
# Iteration 305th: the loss is Variable containing:
# 1.00000e-03 *
#   4.8931
# [torch.FloatTensor of size 1]
#
# Iteration 306th: the loss is Variable containing:
# 1.00000e-03 *
#   4.6788
# [torch.FloatTensor of size 1]
#
# Iteration 307th: the loss is Variable containing:
# 1.00000e-03 *
#   4.4751
# [torch.FloatTensor of size 1]
#
# Iteration 308th: the loss is Variable containing:
# 1.00000e-03 *
#   4.2839
# [torch.FloatTensor of size 1]
#
# Iteration 309th: the loss is Variable containing:
# 1.00000e-03 *
#   4.0981
# [torch.FloatTensor of size 1]
#
# Iteration 310th: the loss is Variable containing:
# 1.00000e-03 *
#   3.9240
# [torch.FloatTensor of size 1]
#
# Iteration 311th: the loss is Variable containing:
# 1.00000e-03 *
#   3.7504
# [torch.FloatTensor of size 1]
#
# Iteration 312th: the loss is Variable containing:
# 1.00000e-03 *
#   3.5907
# [torch.FloatTensor of size 1]
#
# Iteration 313th: the loss is Variable containing:
# 1.00000e-03 *
#   3.4387
# [torch.FloatTensor of size 1]
#
# Iteration 314th: the loss is Variable containing:
# 1.00000e-03 *
#   3.2939
# [torch.FloatTensor of size 1]
#
# Iteration 315th: the loss is Variable containing:
# 1.00000e-03 *
#   3.1578
# [torch.FloatTensor of size 1]
#
# Iteration 316th: the loss is Variable containing:
# 1.00000e-03 *
#   3.0229
# [torch.FloatTensor of size 1]
#
# Iteration 317th: the loss is Variable containing:
# 1.00000e-03 *
#   2.8971
# [torch.FloatTensor of size 1]
#
# Iteration 318th: the loss is Variable containing:
# 1.00000e-03 *
#   2.7778
# [torch.FloatTensor of size 1]
#
# Iteration 319th: the loss is Variable containing:
# 1.00000e-03 *
#   2.6641
# [torch.FloatTensor of size 1]
#
# Iteration 320th: the loss is Variable containing:
# 1.00000e-03 *
#   2.5551
# [torch.FloatTensor of size 1]
#
# Iteration 321th: the loss is Variable containing:
# 1.00000e-03 *
#   2.4477
# [torch.FloatTensor of size 1]
#
# Iteration 322th: the loss is Variable containing:
# 1.00000e-03 *
#   2.3483
# [torch.FloatTensor of size 1]
#
# Iteration 323th: the loss is Variable containing:
# 1.00000e-03 *
#   2.2553
# [torch.FloatTensor of size 1]
#
# Iteration 324th: the loss is Variable containing:
# 1.00000e-03 *
#   2.1618
# [torch.FloatTensor of size 1]
#
# Iteration 325th: the loss is Variable containing:
# 1.00000e-03 *
#   2.0744
# [torch.FloatTensor of size 1]
#
# Iteration 326th: the loss is Variable containing:
# 1.00000e-03 *
#   1.9940
# [torch.FloatTensor of size 1]
#
# Iteration 327th: the loss is Variable containing:
# 1.00000e-03 *
#   1.9127
# [torch.FloatTensor of size 1]
#
# Iteration 328th: the loss is Variable containing:
# 1.00000e-03 *
#   1.8356
# [torch.FloatTensor of size 1]
#
# Iteration 329th: the loss is Variable containing:
# 1.00000e-03 *
#   1.7645
# [torch.FloatTensor of size 1]
#
# Iteration 330th: the loss is Variable containing:
# 1.00000e-03 *
#   1.6990
# [torch.FloatTensor of size 1]
#
# Iteration 331th: the loss is Variable containing:
# 1.00000e-03 *
#   1.6320
# [torch.FloatTensor of size 1]
#
# Iteration 332th: the loss is Variable containing:
# 1.00000e-03 *
#   1.5690
# [torch.FloatTensor of size 1]
#
# Iteration 333th: the loss is Variable containing:
# 1.00000e-03 *
#   1.5082
# [torch.FloatTensor of size 1]
#
# Iteration 334th: the loss is Variable containing:
# 1.00000e-03 *
#   1.4516
# [torch.FloatTensor of size 1]
#
# Iteration 335th: the loss is Variable containing:
# 1.00000e-03 *
#   1.3952
# [torch.FloatTensor of size 1]
#
# Iteration 336th: the loss is Variable containing:
# 1.00000e-03 *
#   1.3427
# [torch.FloatTensor of size 1]
#
# Iteration 337th: the loss is Variable containing:
# 1.00000e-03 *
#   1.2909
# [torch.FloatTensor of size 1]
#
# Iteration 338th: the loss is Variable containing:
# 1.00000e-03 *
#   1.2425
# [torch.FloatTensor of size 1]
#
# Iteration 339th: the loss is Variable containing:
# 1.00000e-03 *
#   1.1970
# [torch.FloatTensor of size 1]
#
# Iteration 340th: the loss is Variable containing:
# 1.00000e-03 *
#   1.1528
# [torch.FloatTensor of size 1]
#
# Iteration 341th: the loss is Variable containing:
# 1.00000e-03 *
#   1.1109
# [torch.FloatTensor of size 1]
#
# Iteration 342th: the loss is Variable containing:
# 1.00000e-03 *
#   1.0711
# [torch.FloatTensor of size 1]
#
# Iteration 343th: the loss is Variable containing:
# 1.00000e-03 *
#   1.0328
# [torch.FloatTensor of size 1]
#
# Iteration 344th: the loss is Variable containing:
# 1.00000e-04 *
#   9.9637
# [torch.FloatTensor of size 1]
#
# Iteration 345th: the loss is Variable containing:
# 1.00000e-04 *
#   9.6000
# [torch.FloatTensor of size 1]
#
# Iteration 346th: the loss is Variable containing:
# 1.00000e-04 *
#   9.2524
# [torch.FloatTensor of size 1]
#
# Iteration 347th: the loss is Variable containing:
# 1.00000e-04 *
#   8.9384
# [torch.FloatTensor of size 1]
#
# Iteration 348th: the loss is Variable containing:
# 1.00000e-04 *
#   8.6278
# [torch.FloatTensor of size 1]
#
# Iteration 349th: the loss is Variable containing:
# 1.00000e-04 *
#   8.3267
# [torch.FloatTensor of size 1]
#
# Iteration 350th: the loss is Variable containing:
# 1.00000e-04 *
#   8.0362
# [torch.FloatTensor of size 1]
#
# Iteration 351th: the loss is Variable containing:
# 1.00000e-04 *
#   7.7644
# [torch.FloatTensor of size 1]
#
# Iteration 352th: the loss is Variable containing:
# 1.00000e-04 *
#   7.5013
# [torch.FloatTensor of size 1]
#
# Iteration 353th: the loss is Variable containing:
# 1.00000e-04 *
#   7.2603
# [torch.FloatTensor of size 1]
#
# Iteration 354th: the loss is Variable containing:
# 1.00000e-04 *
#   7.0112
# [torch.FloatTensor of size 1]
#
# Iteration 355th: the loss is Variable containing:
# 1.00000e-04 *
#   6.7797
# [torch.FloatTensor of size 1]
#
# Iteration 356th: the loss is Variable containing:
# 1.00000e-04 *
#   6.5651
# [torch.FloatTensor of size 1]
#
# Iteration 357th: the loss is Variable containing:
# 1.00000e-04 *
#   6.3385
# [torch.FloatTensor of size 1]
#
# Iteration 358th: the loss is Variable containing:
# 1.00000e-04 *
#   6.1365
# [torch.FloatTensor of size 1]
#
# Iteration 359th: the loss is Variable containing:
# 1.00000e-04 *
#   5.9407
# [torch.FloatTensor of size 1]
#
# Iteration 360th: the loss is Variable containing:
# 1.00000e-04 *
#   5.7629
# [torch.FloatTensor of size 1]
#
# Iteration 361th: the loss is Variable containing:
# 1.00000e-04 *
#   5.5740
# [torch.FloatTensor of size 1]
#
# Iteration 362th: the loss is Variable containing:
# 1.00000e-04 *
#   5.3878
# [torch.FloatTensor of size 1]
#
# Iteration 363th: the loss is Variable containing:
# 1.00000e-04 *
#   5.2295
# [torch.FloatTensor of size 1]
#
# Iteration 364th: the loss is Variable containing:
# 1.00000e-04 *
#   5.0723
# [torch.FloatTensor of size 1]
#
# Iteration 365th: the loss is Variable containing:
# 1.00000e-04 *
#   4.9178
# [torch.FloatTensor of size 1]
#
# Iteration 366th: the loss is Variable containing:
# 1.00000e-04 *
#   4.7666
# [torch.FloatTensor of size 1]
#
# Iteration 367th: the loss is Variable containing:
# 1.00000e-04 *
#   4.6210
# [torch.FloatTensor of size 1]
#
# Iteration 368th: the loss is Variable containing:
# 1.00000e-04 *
#   4.4818
# [torch.FloatTensor of size 1]
#
# Iteration 369th: the loss is Variable containing:
# 1.00000e-04 *
#   4.3480
# [torch.FloatTensor of size 1]
#
# Iteration 370th: the loss is Variable containing:
# 1.00000e-04 *
#   4.2245
# [torch.FloatTensor of size 1]
#
# Iteration 371th: the loss is Variable containing:
# 1.00000e-04 *
#   4.0972
# [torch.FloatTensor of size 1]
#
# Iteration 372th: the loss is Variable containing:
# 1.00000e-04 *
#   3.9747
# [torch.FloatTensor of size 1]
#
# Iteration 373th: the loss is Variable containing:
# 1.00000e-04 *
#   3.8546
# [torch.FloatTensor of size 1]
#
# Iteration 374th: the loss is Variable containing:
# 1.00000e-04 *
#   3.7398
# [torch.FloatTensor of size 1]
#
# Iteration 375th: the loss is Variable containing:
# 1.00000e-04 *
#   3.6334
# [torch.FloatTensor of size 1]
#
# Iteration 376th: the loss is Variable containing:
# 1.00000e-04 *
#   3.5333
# [torch.FloatTensor of size 1]
#
# Iteration 377th: the loss is Variable containing:
# 1.00000e-04 *
#   3.4217
# [torch.FloatTensor of size 1]
#
# Iteration 378th: the loss is Variable containing:
# 1.00000e-04 *
#   3.3315
# [torch.FloatTensor of size 1]
#
# Iteration 379th: the loss is Variable containing:
# 1.00000e-04 *
#   3.2386
# [torch.FloatTensor of size 1]
#
# Iteration 380th: the loss is Variable containing:
# 1.00000e-04 *
#   3.1544
# [torch.FloatTensor of size 1]
#
# Iteration 381th: the loss is Variable containing:
# 1.00000e-04 *
#   3.0641
# [torch.FloatTensor of size 1]
#
# Iteration 382th: the loss is Variable containing:
# 1.00000e-04 *
#   2.9680
# [torch.FloatTensor of size 1]
#
# Iteration 383th: the loss is Variable containing:
# 1.00000e-04 *
#   2.8902
# [torch.FloatTensor of size 1]
#
# Iteration 384th: the loss is Variable containing:
# 1.00000e-04 *
#   2.8179
# [torch.FloatTensor of size 1]
#
# Iteration 385th: the loss is Variable containing:
# 1.00000e-04 *
#   2.7442
# [torch.FloatTensor of size 1]
#
# Iteration 386th: the loss is Variable containing:
# 1.00000e-04 *
#   2.6823
# [torch.FloatTensor of size 1]
#
# Iteration 387th: the loss is Variable containing:
# 1.00000e-04 *
#   2.6105
# [torch.FloatTensor of size 1]
#
# Iteration 388th: the loss is Variable containing:
# 1.00000e-04 *
#   2.5441
# [torch.FloatTensor of size 1]
#
# Iteration 389th: the loss is Variable containing:
# 1.00000e-04 *
#   2.4817
# [torch.FloatTensor of size 1]
#
# Iteration 390th: the loss is Variable containing:
# 1.00000e-04 *
#   2.4093
# [torch.FloatTensor of size 1]
#
# Iteration 391th: the loss is Variable containing:
# 1.00000e-04 *
#   2.3448
# [torch.FloatTensor of size 1]
#
# Iteration 392th: the loss is Variable containing:
# 1.00000e-04 *
#   2.2852
# [torch.FloatTensor of size 1]
#
# Iteration 393th: the loss is Variable containing:
# 1.00000e-04 *
#   2.2298
# [torch.FloatTensor of size 1]
# Iteration 394th: the loss is Variable containing:
# 1.00000e-04 *
#   2.1739
# [torch.FloatTensor of size 1]
#
# Iteration 395th: the loss is Variable containing:
# 1.00000e-04 *
#   2.1249
# [torch.FloatTensor of size 1]
#
# Iteration 396th: the loss is Variable containing:
# 1.00000e-04 *
#   2.0693
# [torch.FloatTensor of size 1]
#
# Iteration 397th: the loss is Variable containing:
# 1.00000e-04 *
#   2.0214
# [torch.FloatTensor of size 1]
#
# Iteration 398th: the loss is Variable containing:
# 1.00000e-04 *
#   1.9747
# [torch.FloatTensor of size 1]
#
# Iteration 399th: the loss is Variable containing:
# 1.00000e-04 *
#   1.9237
# [torch.FloatTensor of size 1]
#
# Iteration 400th: the loss is Variable containing:
# 1.00000e-04 *
#   1.8857
# [torch.FloatTensor of size 1]
#
# Iteration 401th: the loss is Variable containing:
# 1.00000e-04 *
#   1.8430
# [torch.FloatTensor of size 1]
#
# Iteration 402th: the loss is Variable containing:
# 1.00000e-04 *
#   1.7994
# [torch.FloatTensor of size 1]
#
# Iteration 403th: the loss is Variable containing:
# 1.00000e-04 *
#   1.7602
# [torch.FloatTensor of size 1]
#
# Iteration 404th: the loss is Variable containing:
# 1.00000e-04 *
#   1.7178
# [torch.FloatTensor of size 1]
#
# Iteration 405th: the loss is Variable containing:
# 1.00000e-04 *
#   1.6758
# [torch.FloatTensor of size 1]
#
# Iteration 406th: the loss is Variable containing:
# 1.00000e-04 *
#   1.6382
# [torch.FloatTensor of size 1]
#
# Iteration 407th: the loss is Variable containing:
# 1.00000e-04 *
#   1.6032
# [torch.FloatTensor of size 1]
#
# Iteration 408th: the loss is Variable containing:
# 1.00000e-04 *
#   1.5684
# [torch.FloatTensor of size 1]
#
# Iteration 409th: the loss is Variable containing:
# 1.00000e-04 *
#   1.5366
# [torch.FloatTensor of size 1]
#
# Iteration 410th: the loss is Variable containing:
# 1.00000e-04 *
#   1.4996
# [torch.FloatTensor of size 1]
#
# Iteration 411th: the loss is Variable containing:
# 1.00000e-04 *
#   1.4668
# [torch.FloatTensor of size 1]
#
# Iteration 412th: the loss is Variable containing:
# 1.00000e-04 *
#   1.4351
# [torch.FloatTensor of size 1]
#
# Iteration 413th: the loss is Variable containing:
# 1.00000e-04 *
#   1.4081
# [torch.FloatTensor of size 1]
#
# Iteration 414th: the loss is Variable containing:
# 1.00000e-04 *
#   1.3756
# [torch.FloatTensor of size 1]
#
# Iteration 415th: the loss is Variable containing:
# 1.00000e-04 *
#   1.3487
# [torch.FloatTensor of size 1]
#
# Iteration 416th: the loss is Variable containing:
# 1.00000e-04 *
#   1.3196
# [torch.FloatTensor of size 1]
#
# Iteration 417th: the loss is Variable containing:
# 1.00000e-04 *
#   1.2913
# [torch.FloatTensor of size 1]
#
# Iteration 418th: the loss is Variable containing:
# 1.00000e-04 *
#   1.2678
# [torch.FloatTensor of size 1]
#
# Iteration 419th: the loss is Variable containing:
# 1.00000e-04 *
#   1.2396
# [torch.FloatTensor of size 1]
#
# Iteration 420th: the loss is Variable containing:
# 1.00000e-04 *
#   1.2128
# [torch.FloatTensor of size 1]
#
# Iteration 421th: the loss is Variable containing:
# 1.00000e-04 *
#   1.1933
# [torch.FloatTensor of size 1]
#
# Iteration 422th: the loss is Variable containing:
# 1.00000e-04 *
#   1.1687
# [torch.FloatTensor of size 1]
#
# Iteration 423th: the loss is Variable containing:
# 1.00000e-04 *
#   1.1448
# [torch.FloatTensor of size 1]
#
# Iteration 424th: the loss is Variable containing:
# 1.00000e-04 *
#   1.1238
# [torch.FloatTensor of size 1]
#
# Iteration 425th: the loss is Variable containing:
# 1.00000e-04 *
#   1.0990
# [torch.FloatTensor of size 1]
#
# Iteration 426th: the loss is Variable containing:
# 1.00000e-04 *
#   1.0773
# [torch.FloatTensor of size 1]
#
# Iteration 427th: the loss is Variable containing:
# 1.00000e-04 *
#   1.0570
# [torch.FloatTensor of size 1]
#
# Iteration 428th: the loss is Variable containing:
# 1.00000e-04 *
#   1.0353
# [torch.FloatTensor of size 1]
#
# Iteration 429th: the loss is Variable containing:
# 1.00000e-04 *
#   1.0173
# [torch.FloatTensor of size 1]
#
# Iteration 430th: the loss is Variable containing:
# 1.00000e-05 *
#   9.9593
# [torch.FloatTensor of size 1]
#
# Iteration 431th: the loss is Variable containing:
# 1.00000e-05 *
#   9.7519
# [torch.FloatTensor of size 1]
#
# Iteration 432th: the loss is Variable containing:
# 1.00000e-05 *
#   9.5768
# [torch.FloatTensor of size 1]
#
# Iteration 433th: the loss is Variable containing:
# 1.00000e-05 *
#   9.4146
# [torch.FloatTensor of size 1]
#
# Iteration 434th: the loss is Variable containing:
# 1.00000e-05 *
#   9.2169
# [torch.FloatTensor of size 1]
#
# Iteration 435th: the loss is Variable containing:
# 1.00000e-05 *
#   9.0599
# [torch.FloatTensor of size 1]
#
# Iteration 436th: the loss is Variable containing:
# 1.00000e-05 *
#   8.9101
# [torch.FloatTensor of size 1]
#
# Iteration 437th: the loss is Variable containing:
# 1.00000e-05 *
#   8.7291
# [torch.FloatTensor of size 1]
#
# Iteration 438th: the loss is Variable containing:
# 1.00000e-05 *
#   8.5555
# [torch.FloatTensor of size 1]
#
# Iteration 439th: the loss is Variable containing:
# 1.00000e-05 *
#   8.4265
# [torch.FloatTensor of size 1]
#
# Iteration 440th: the loss is Variable containing:
# 1.00000e-05 *
#   8.3002
# [torch.FloatTensor of size 1]
#
# Iteration 441th: the loss is Variable containing:
# 1.00000e-05 *
#   8.1176
# [torch.FloatTensor of size 1]
#
# Iteration 442th: the loss is Variable containing:
# 1.00000e-05 *
#   7.9668
# [torch.FloatTensor of size 1]
#
# Iteration 443th: the loss is Variable containing:
# 1.00000e-05 *
#   7.8002
# [torch.FloatTensor of size 1]
#
# Iteration 444th: the loss is Variable containing:
# 1.00000e-05 *
#   7.6983
# [torch.FloatTensor of size 1]
#
# Iteration 445th: the loss is Variable containing:
# 1.00000e-05 *
#   7.5619
# [torch.FloatTensor of size 1]
#
# Iteration 446th: the loss is Variable containing:
# 1.00000e-05 *
#   7.4353
# [torch.FloatTensor of size 1]
#
# Iteration 447th: the loss is Variable containing:
# 1.00000e-05 *
#   7.3204
# [torch.FloatTensor of size 1]
#
# Iteration 448th: the loss is Variable containing:
# 1.00000e-05 *
#   7.2227
# [torch.FloatTensor of size 1]
#
# Iteration 449th: the loss is Variable containing:
# 1.00000e-05 *
#   7.0919
# [torch.FloatTensor of size 1]
#
# Iteration 450th: the loss is Variable containing:
# 1.00000e-05 *
#   6.9807
# [torch.FloatTensor of size 1]
#
# Iteration 451th: the loss is Variable containing:
# 1.00000e-05 *
#   6.8563
# [torch.FloatTensor of size 1]
#
# Iteration 452th: the loss is Variable containing:
# 1.00000e-05 *
#   6.7260
# [torch.FloatTensor of size 1]
#
# Iteration 453th: the loss is Variable containing:
# 1.00000e-05 *
#   6.5976
# [torch.FloatTensor of size 1]
#
# Iteration 454th: the loss is Variable containing:
# 1.00000e-05 *
#   6.5005
# [torch.FloatTensor of size 1]
#
# Iteration 455th: the loss is Variable containing:
# 1.00000e-05 *
#   6.3979
# [torch.FloatTensor of size 1]
#
# Iteration 456th: the loss is Variable containing:
# 1.00000e-05 *
#   6.3053
# [torch.FloatTensor of size 1]
#
# Iteration 457th: the loss is Variable containing:
# 1.00000e-05 *
#   6.1918
# [torch.FloatTensor of size 1]
#
# Iteration 458th: the loss is Variable containing:
# 1.00000e-05 *
#   6.0893
# [torch.FloatTensor of size 1]
#
# Iteration 459th: the loss is Variable containing:
# 1.00000e-05 *
#   6.0020
# [torch.FloatTensor of size 1]
#
# Iteration 460th: the loss is Variable containing:
# 1.00000e-05 *
#   5.9202
# [torch.FloatTensor of size 1]
#
# Iteration 461th: the loss is Variable containing:
# 1.00000e-05 *
#   5.8300
# [torch.FloatTensor of size 1]
#
# Iteration 462th: the loss is Variable containing:
# 1.00000e-05 *
#   5.7385
# [torch.FloatTensor of size 1]
#
# Iteration 463th: the loss is Variable containing:
# 1.00000e-05 *
#   5.6324
# [torch.FloatTensor of size 1]
#
# Iteration 464th: the loss is Variable containing:
# 1.00000e-05 *
#   5.5387
# [torch.FloatTensor of size 1]
#
# Iteration 465th: the loss is Variable containing:
# 1.00000e-05 *
#   5.4510
# [torch.FloatTensor of size 1]
#
# Iteration 466th: the loss is Variable containing:
# 1.00000e-05 *
#   5.3271
# [torch.FloatTensor of size 1]
#
# Iteration 467th: the loss is Variable containing:
# 1.00000e-05 *
#   5.2706
# [torch.FloatTensor of size 1]
#
# Iteration 468th: the loss is Variable containing:
# 1.00000e-05 *
#   5.2153
# [torch.FloatTensor of size 1]
#
# Iteration 469th: the loss is Variable containing:
# 1.00000e-05 *
#   5.1197
# [torch.FloatTensor of size 1]
#
# Iteration 470th: the loss is Variable containing:
# 1.00000e-05 *
#   5.0566
# [torch.FloatTensor of size 1]
#
# Iteration 471th: the loss is Variable containing:
# 1.00000e-05 *
#   4.9891
# [torch.FloatTensor of size 1]
#
# Iteration 472th: the loss is Variable containing:
# 1.00000e-05 *
#   4.9114
# [torch.FloatTensor of size 1]
#
# Iteration 473th: the loss is Variable containing:
# 1.00000e-05 *
#   4.8131
# [torch.FloatTensor of size 1]
#
# Iteration 474th: the loss is Variable containing:
# 1.00000e-05 *
#   4.7344
# [torch.FloatTensor of size 1]
#
# Iteration 475th: the loss is Variable containing:
# 1.00000e-05 *
#   4.6687
# [torch.FloatTensor of size 1]
#
# Iteration 476th: the loss is Variable containing:
# 1.00000e-05 *
#   4.5923
# [torch.FloatTensor of size 1]
#
# Iteration 477th: the loss is Variable containing:
# 1.00000e-05 *
#   4.5516
# [torch.FloatTensor of size 1]
#
# Iteration 478th: the loss is Variable containing:
# 1.00000e-05 *
#   4.4660
# [torch.FloatTensor of size 1]
#
# Iteration 479th: the loss is Variable containing:
# 1.00000e-05 *
#   4.3925
# [torch.FloatTensor of size 1]
#
# Iteration 480th: the loss is Variable containing:
# 1.00000e-05 *
#   4.3527
# [torch.FloatTensor of size 1]
#
# Iteration 481th: the loss is Variable containing:
# 1.00000e-05 *
#   4.2822
# [torch.FloatTensor of size 1]
#
# Iteration 482th: the loss is Variable containing:
# 1.00000e-05 *
#   4.2054
# [torch.FloatTensor of size 1]
#
# Iteration 483th: the loss is Variable containing:
# 1.00000e-05 *
#   4.1729
# [torch.FloatTensor of size 1]
#
# Iteration 484th: the loss is Variable containing:
# 1.00000e-05 *
#   4.0928
# [torch.FloatTensor of size 1]
#
# Iteration 485th: the loss is Variable containing:
# 1.00000e-05 *
#   4.0473
# [torch.FloatTensor of size 1]
#
# Iteration 486th: the loss is Variable containing:
# 1.00000e-05 *
#   4.0074
# [torch.FloatTensor of size 1]
#
# Iteration 487th: the loss is Variable containing:
# 1.00000e-05 *
#   3.9371
# [torch.FloatTensor of size 1]
#
# Iteration 488th: the loss is Variable containing:
# 1.00000e-05 *
#   3.8847
# [torch.FloatTensor of size 1]
#
# Iteration 489th: the loss is Variable containing:
# 1.00000e-05 *
#   3.8198
# [torch.FloatTensor of size 1]
#
# Iteration 490th: the loss is Variable containing:
# 1.00000e-05 *
#   3.7838
# [torch.FloatTensor of size 1]
#
# Iteration 491th: the loss is Variable containing:
# 1.00000e-05 *
#   3.7451
# [torch.FloatTensor of size 1]
#
# Iteration 492th: the loss is Variable containing:
# 1.00000e-05 *
#   3.6850
# [torch.FloatTensor of size 1]
#
# Iteration 493th: the loss is Variable containing:
# 1.00000e-05 *
#   3.6540
# [torch.FloatTensor of size 1]
#
# Iteration 494th: the loss is Variable containing:
# 1.00000e-05 *
#   3.6128
# [torch.FloatTensor of size 1]
#
# Iteration 495th: the loss is Variable containing:
# 1.00000e-05 *
#   3.5569
# [torch.FloatTensor of size 1]
#
# Iteration 496th: the loss is Variable containing:
# 1.00000e-05 *
#   3.5302
# [torch.FloatTensor of size 1]
#
# Iteration 497th: the loss is Variable containing:
# 1.00000e-05 *
#   3.4815
# [torch.FloatTensor of size 1]
#
# Iteration 498th: the loss is Variable containing:
# 1.00000e-05 *
#   3.4392
# [torch.FloatTensor of size 1]
#
# Iteration 499th: the loss is Variable containing:
# 1.00000e-05 *
#   3.3816
# [torch.FloatTensor of size 1]
